# %% [markdown]
# # Data Processing Pipeline Tests

# %%
import polars as pl
import glob

queries = []
for file in glob.glob("../data/processed/training_alerts_v3/AGN/*"):
    q = pl.scan_csv(file)
    queries.append(q)

dataframes = pl.collect_all(queries)
print(dataframes)
# Out:
# [shape: (76798180, 18)
# ┌──────────┬──────────┬──────┬─────────────┬─────┬────────────┬────────────┬────────────┬──────────┐
# │ SNID     ┆ candid   ┆ type ┆ RA          ┆ ... ┆ MJD        ┆ FLUXCAL    ┆ FLUXCALERR ┆ PHOTFLAG │
# │ ---      ┆ ---      ┆ ---  ┆ ---         ┆     ┆ ---        ┆ ---        ┆ ---        ┆ ---      │
# │ i64      ┆ i64      ┆ str  ┆ f64         ┆     ┆ f64        ┆ f64        ┆ f64        ┆ i64      │
# ╞══════════╪══════════╪══════╪═════════════╪═════╪════════════╪════════════╪════════════╪══════════╡
# │ 50760233 ┆ 30792462 ┆ AGN  ┆ 319.082387  ┆ ... ┆ 60616.0639 ┆ -13.539796 ┆ 1.5222188  ┆ 6144     │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 50760233 ┆ 30792463 ┆ AGN  ┆ 319.082387  ┆ ... ┆ 60588.1126 ┆ -6.701034  ┆ 5.0582013  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 50760233 ┆ 30792463 ┆ AGN  ┆ 319.082387  ┆ ... ┆ 60588.1289 ┆ -25.990084 ┆ 7.1148524  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 50760233 ┆ 30792463 ┆ AGN  ┆ 319.082387  ┆ ... ┆ 60593.085  ┆ -1.425134  ┆ 20.441166  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ ...      ┆ ...      ┆ ...  ┆ ...         ┆ ... ┆ ...        ┆ ...        ┆ ...        ┆ ...      │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 42453727 ┆ 28999233 ┆ AGN  ┆ 179.843894  ┆ ... ┆ 61176.0088 ┆ -17.301907 ┆ 2.787369   ┆ 4096     │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 42453727 ┆ 28999233 ┆ AGN  ┆ 179.843894  ┆ ... ┆ 61176.0258 ┆ -9.663094  ┆ 4.4170265  ┆ 4096     │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 42453727 ┆ 28999233 ┆ AGN  ┆ 179.843894  ┆ ... ┆ 61177.0064 ┆ -19.222393 ┆ 2.7739432  ┆ 4096     │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 42453727 ┆ 28999233 ┆ AGN  ┆ 179.843894  ┆ ... ┆ 61177.0233 ┆ -18.192436 ┆ 3.2176657  ┆ 4096     │
# └──────────┴──────────┴──────┴─────────────┴─────┴────────────┴────────────┴────────────┴──────────┘, shape: (34407184, 18)
# ┌──────────┬──────────┬──────┬─────────────┬─────┬────────────┬────────────┬────────────┬──────────┐
# │ SNID     ┆ candid   ┆ type ┆ RA          ┆ ... ┆ MJD        ┆ FLUXCAL    ┆ FLUXCALERR ┆ PHOTFLAG │
# │ ---      ┆ ---      ┆ ---  ┆ ---         ┆     ┆ ---        ┆ ---        ┆ ---        ┆ ---      │
# │ i64      ┆ i64      ┆ str  ┆ f64         ┆     ┆ f64        ┆ f64        ┆ f64        ┆ i64      │
# ╞══════════╪══════════╪══════╪═════════════╪═════╪════════════╪════════════╪════════════╪══════════╡
# │ 50760233 ┆ 30792462 ┆ AGN  ┆ 319.082387  ┆ ... ┆ 60616.0639 ┆ -13.539796 ┆ 1.5222188  ┆ 6144     │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 50760233 ┆ 30792463 ┆ AGN  ┆ 319.082387  ┆ ... ┆ 60588.1126 ┆ -6.701034  ┆ 5.0582013  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 50760233 ┆ 30792463 ┆ AGN  ┆ 319.082387  ┆ ... ┆ 60588.1289 ┆ -25.990084 ┆ 7.1148524  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 50760233 ┆ 30792463 ┆ AGN  ┆ 319.082387  ┆ ... ┆ 60593.085  ┆ -1.425134  ┆ 20.441166  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ ...      ┆ ...      ┆ ...  ┆ ...         ┆ ... ┆ ...        ┆ ...        ┆ ...        ┆ ...      │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 35765786 ┆ 31775782 ┆ AGN  ┆ 328.921437  ┆ ... ┆ 60966.1099 ┆ 14.548375  ┆ 3.4228218  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 35765786 ┆ 31775782 ┆ AGN  ┆ 328.921437  ┆ ... ┆ 60966.1265 ┆ 13.39562   ┆ 6.9865804  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 35765786 ┆ 31775782 ┆ AGN  ┆ 328.921437  ┆ ... ┆ 60972.0342 ┆ 37.228493  ┆ 6.9975567  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 35765786 ┆ 31775782 ┆ AGN  ┆ 328.921437  ┆ ... ┆ 60972.0513 ┆ 19.21665   ┆ 2.6502936  ┆ 4096     │
# └──────────┴──────────┴──────┴─────────────┴─────┴────────────┴────────────┴────────────┴──────────┘]

# %%
# pdf = dataframes[30].to_pandas()

# %%
pldf = pl.concat(dataframes)

# %%
pldf
# Out:
# shape: (111205364, 18)
# ┌──────────┬──────────┬──────┬─────────────┬─────┬────────────┬────────────┬────────────┬──────────┐
# │ SNID     ┆ candid   ┆ type ┆ RA          ┆ ... ┆ MJD        ┆ FLUXCAL    ┆ FLUXCALERR ┆ PHOTFLAG │
# │ ---      ┆ ---      ┆ ---  ┆ ---         ┆     ┆ ---        ┆ ---        ┆ ---        ┆ ---      │
# │ i64      ┆ i64      ┆ str  ┆ f64         ┆     ┆ f64        ┆ f64        ┆ f64        ┆ i64      │
# ╞══════════╪══════════╪══════╪═════════════╪═════╪════════════╪════════════╪════════════╪══════════╡
# │ 50760233 ┆ 30792462 ┆ AGN  ┆ 319.082387  ┆ ... ┆ 60616.0639 ┆ -13.539796 ┆ 1.5222188  ┆ 6144     │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 50760233 ┆ 30792463 ┆ AGN  ┆ 319.082387  ┆ ... ┆ 60588.1126 ┆ -6.701034  ┆ 5.0582013  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 50760233 ┆ 30792463 ┆ AGN  ┆ 319.082387  ┆ ... ┆ 60588.1289 ┆ -25.990084 ┆ 7.1148524  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 50760233 ┆ 30792463 ┆ AGN  ┆ 319.082387  ┆ ... ┆ 60593.085  ┆ -1.425134  ┆ 20.441166  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ ...      ┆ ...      ┆ ...  ┆ ...         ┆ ... ┆ ...        ┆ ...        ┆ ...        ┆ ...      │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 35765786 ┆ 31775782 ┆ AGN  ┆ 328.921437  ┆ ... ┆ 60966.1099 ┆ 14.548375  ┆ 3.4228218  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 35765786 ┆ 31775782 ┆ AGN  ┆ 328.921437  ┆ ... ┆ 60966.1265 ┆ 13.39562   ┆ 6.9865804  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 35765786 ┆ 31775782 ┆ AGN  ┆ 328.921437  ┆ ... ┆ 60972.0342 ┆ 37.228493  ┆ 6.9975567  ┆ 0        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 35765786 ┆ 31775782 ┆ AGN  ┆ 328.921437  ┆ ... ┆ 60972.0513 ┆ 19.21665   ┆ 2.6502936  ┆ 4096     │
# └──────────┴──────────┴──────┴─────────────┴─────┴────────────┴────────────┴────────────┴──────────┘

# %%
pldf.select(pl.col("HOSTGAL_PHOTOZ").unique())
# Out:
# shape: (21642, 1)
# ┌────────────────┐
# │ HOSTGAL_PHOTOZ │
# │ ---            │
# │ f64            │
# ╞════════════════╡
# │ 0.057491       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.0599         │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.067579       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.0682         │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2.9577975      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2.9686947      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2.9803371      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ -9.0           │
# └────────────────┘

# %%
import numpy as np
np.unique(pldf["HOSTGAL_PHOTOZ"])
# Out:
# array([-9.])

# %%
pdf = pldf.to_pandas()

# %%
pdf
# Out:
#                SNID    candid type          RA        DEC  HOSTGAL_PHOTOZ  \
# 0          50760233  30792462  AGN  319.082387 -34.000487        0.514471
# 1          50760233  30792463  AGN  319.082387 -34.000487        0.514471
# 2          50760233  30792463  AGN  319.082387 -34.000487        0.514471
# 3          50760233  30792463  AGN  319.082387 -34.000487        0.514471
# 4          50760233  30792463  AGN  319.082387 -34.000487        0.514471
# ...             ...       ...  ...         ...        ...             ...
# 111205359  35765786  31775782  AGN  328.921437 -52.033881        0.446655
# 111205360  35765786  31775782  AGN  328.921437 -52.033881        0.446655
# 111205361  35765786  31775782  AGN  328.921437 -52.033881        0.446655
# 111205362  35765786  31775782  AGN  328.921437 -52.033881        0.446655
# 111205363  35765786  31775782  AGN  328.921437 -52.033881        0.446655
#
#            HOSTGAL_PHOTOZ_ERR  HOSTGAL_RA  HOSTGAL_DEC     MWEBV  MWEBV_ERR  \
# 0                     0.04076  319.082400   -34.000511  0.090136   0.004507
# 1                     0.04076  319.082400   -34.000511  0.090136   0.004507
# 2                     0.04076  319.082400   -34.000511  0.090136   0.004507
# 3                     0.04076  319.082400   -34.000511  0.090136   0.004507
# 4                     0.04076  319.082400   -34.000511  0.090136   0.004507
# ...                       ...         ...          ...       ...        ...
# 111205359             0.03850  328.921442   -52.033886  0.020521   0.001026
# 111205360             0.03850  328.921442   -52.033886  0.020521   0.001026
# 111205361             0.03850  328.921442   -52.033886  0.020521   0.001026
# 111205362             0.03850  328.921442   -52.033886  0.020521   0.001026
# 111205363             0.03850  328.921442   -52.033886  0.020521   0.001026
#
#            REDSHIFT_HELIO  REDSHIFT_HELIO_ERR BAND         MJD    FLUXCAL  \
# 0                0.480695               0.001    g  60616.0639 -13.539796
# 1                0.480695               0.001    r  60588.1126  -6.701034
# 2                0.480695               0.001    i  60588.1289 -25.990084
# 3                0.480695               0.001    z  60593.0850  -1.425134
# 4                0.480695               0.001    Y  60593.1019 -44.701733
# ...                   ...                 ...  ...         ...        ...
# 111205359        0.432163               0.001    z  60960.0965  21.665092
# 111205360        0.432163               0.001    r  60966.1099  14.548375
# 111205361        0.432163               0.001    i  60966.1265  13.395620
# 111205362        0.432163               0.001    u  60972.0342  37.228493
# 111205363        0.432163               0.001    g  60972.0513  19.216650
#
#            FLUXCALERR  PHOTFLAG
# 0            1.522219      6144
# 1            5.058201         0
# 2            7.114852         0
# 3           20.441166         0
# 4           28.839968         0
# ...               ...       ...
# 111205359    9.563851         0
# 111205360    3.422822         0
# 111205361    6.986580         0
# 111205362    6.997557         0
# 111205363    2.650294      4096
#
# [111205364 rows x 18 columns]

# %%
import astronet

from astronet.preprocess import (
    __filter_dataframe_only_supernova,
    __transient_trim,
    generate_gp_all_objects,
    one_hot_encode,
    remap_filters,
    robust_scale,
    predict_2d_gp,
    fit_2d_gp,
)

# %%
pdf.rename(
        {"SIM_Z": "hostgal_photoz", "FLUXCAL": "flux", "FLUXCALERR": "flux_error", "MJD": "mjd", "candid": "object_id", "type": "target", "BAND": "passband"},
    axis="columns", inplace=True
)  # snmachine and PLAsTiCC uses a different denomination

# %%
df = pdf.filter(
    items=[
    "mjd",
    "flux",
    "flux_error",
    "hostgal_photoz",
    "passband",
    "object_id",
    "target",
    ]
)

# %%
ELASTICC_FILTER_MAP = {
    "u": "lsstu",
    "g": "lsstg",
    "r": "lsstr",
    "i": "lssti",
    "z": "lsstz",
    "Y": "lssty",
}

# Central passbands wavelengths
ELASTICC_PB_WAVELENGTHS = {
    "lsstu": 3685.0,
    "lsstg": 4802.0,
    "lsstr": 6231.0,
    "lssti": 7542.0,
    "lsstz": 8690.0,
    "lssty": 9736.0,
}

ELASTICC_PB_COLORS = {
    "lsstu": "#984ea3",  # Purple: https://www.color-hex.com/color/984ea3
    "lsstg": "#4daf4a",  # Green: https://www.color-hex.com/color/4daf4a
    "lsstr": "#e41a1c",  # Red: https://www.color-hex.com/color/e41a1c
    "lssti": "#377eb8",  # Blue: https://www.color-hex.com/color/377eb8
    "lsstz": "#ff7f00",  # Orange: https://www.color-hex.com/color/ff7f00
    "lssty": "#e3c530",  # Yellow: https://www.color-hex.com/color/e3c530
}

# %%
df
# Out:
#                  mjd       flux  flux_error  hostgal_photoz passband  \
# 0         61287.2341  27.084452    2.857522        0.851393        g
# 1         61262.3531  24.935242    3.548370        0.851393        g
# 2         61287.2341  27.084452    2.857522        0.851393        g
# 3         61262.3700  18.187544    6.185833        0.851393        r
# 4         61287.2513  28.800117    3.306518        0.851393        r
# ...              ...        ...         ...             ...      ...
# 22805031  61106.2230  47.988934   28.085463        0.233093        Y
# 22805032  61133.1960  60.923851   20.094168        0.233093        Y
# 22805033  61160.0577  41.361073   30.517502        0.233093        Y
# 22805034  61161.0964 -21.530848   33.843861        0.233093        Y
# 22805035  61190.0752  -6.008811   31.024376        0.233093        Y
#
#           object_id target
# 0          32152815    TDE
# 1          32152816    TDE
# 2          32152816    TDE
# 3          32152816    TDE
# 4          32152816    TDE
# ...             ...    ...
# 22805031   32052759    TDE
# 22805032   32052759    TDE
# 22805033   32052759    TDE
# 22805034   32052759    TDE
# 22805035   32052759    TDE
#
# [22805036 rows x 7 columns]

# %%
df = remap_filters(df, filter_map=ELASTICC_FILTER_MAP)

# %%
df
# Out:
#                  mjd       flux  flux_error  hostgal_photoz filter  object_id  \
# 0         61287.2341  27.084452    2.857522        0.851393  lsstg   32152815
# 1         61262.3531  24.935242    3.548370        0.851393  lsstg   32152816
# 2         61287.2341  27.084452    2.857522        0.851393  lsstg   32152816
# 3         61262.3700  18.187544    6.185833        0.851393  lsstr   32152816
# 4         61287.2513  28.800117    3.306518        0.851393  lsstr   32152816
# ...              ...        ...         ...             ...    ...        ...
# 22805031  61106.2230  47.988934   28.085463        0.233093  lssty   32052759
# 22805032  61133.1960  60.923851   20.094168        0.233093  lssty   32052759
# 22805033  61160.0577  41.361073   30.517502        0.233093  lssty   32052759
# 22805034  61161.0964 -21.530848   33.843861        0.233093  lssty   32052759
# 22805035  61190.0752  -6.008811   31.024376        0.233093  lssty   32052759
#
#          target
# 0           TDE
# 1           TDE
# 2           TDE
# 3           TDE
# 4           TDE
# ...         ...
# 22805031    TDE
# 22805032    TDE
# 22805033    TDE
# 22805034    TDE
# 22805035    TDE
#
# [22805036 rows x 7 columns]

# %%
import numpy as np
filters = df["filter"]
filters = list(np.unique(filters))
filters
# Out:
# ['lsstg', 'lssti', 'lsstr', 'lsstu', 'lssty', 'lsstz']

# %%
pb_wavelengths = ELASTICC_PB_WAVELENGTHS
pb_wavelengths
# Out:
# {'lsstu': 3685.0,
#  'lsstg': 4802.0,
#  'lsstr': 6231.0,
#  'lssti': 7542.0,
#  'lsstz': 8690.0,
#  'lssty': 9736.0}

# %%
object_list = list(np.unique(df["object_id"]))
len(object_list)
# Out:
# 997204

# %%
obs_transient = df
generated_gp_dataset = generate_gp_all_objects(
    object_list, obs_transient, timesteps=100, pb_wavelengths=ELASTICC_PB_WAVELENGTHS
)
# Out:
# COMPLETED OBJECT ID:31831435
# COMPLETED OBJECT ID:31532860
# COMPLETED OBJECT ID:31947486
# SKIPPING OBJECT ID:31470390, ONLY 4 FILTER RECORDED
# SKIPPING OBJECT ID:32086223, ONLY 5 FILTER RECORDED
# COMPLETED OBJECT ID:32273462
# COMPLETED OBJECT ID:31684599
# SKIPPING OBJECT ID:31504756, ONLY 4 FILTER RECORDED
# COMPLETED OBJECT ID:32257452
# SKIPPING OBJECT ID:32158742, ONLY 5 FILTER RECORDED
# SKIPPING OBJECT ID:31951082, ONLY 5 FILTER RECORDED
# SKIPPING OBJECT ID:31963401, ONLY 1 FILTER RECORDED
# SKIPPING OBJECT ID:32243400, ONLY 5 FILTER RECORDED
# COMPLETED OBJECT ID:32413088
# COMPLETED OBJECT ID:31878596
# COMPLETED OBJECT ID:32220480
# COMPLETED OBJECT ID:31548172
# SKIPPING OBJECT ID:31944418, ONLY 1 FILTER RECORDED
# COMPLETED OBJECT ID:32376054
# COMPLETED OBJECT ID:32292100
# SKIPPING OBJECT ID:32143221, ONLY 1 FILTER RECORDED
# SKIPPING OBJECT ID:31899262, ONLY 4 FILTER RECORDED
# COMPLETED OBJECT ID:31695669
# SKIPPING OBJECT ID:31914833, ONLY 4 FILTER RECORDED
# SKIPPING OBJECT ID:31783468, ONLY 3 FILTER RECORDED
# COMPLETED OBJECT ID:31567047
# SKIPPING OBJECT ID:32332004, ONLY 3 FILTER RECORDED
# SKIPPING OBJECT ID:31789360, ONLY 5 FILTER RECORDED
# COMPLETED OBJECT ID:31700590
# COMPLETED OBJECT ID:32206173
# SKIPPING OBJECT ID:31971930, ONLY 5 FILTER RECORDED
# COMPLETED OBJECT ID:32043520
# SKIPPING OBJECT ID:32080615, ONLY 2 FILTER RECORDED
# SKIPPING OBJECT ID:31774403, ONLY 5 FILTER RECORDED
# COMPLETED OBJECT ID:32317733
# COMPLETED OBJECT ID:31923566
# COMPLETED OBJECT ID:31682079
# COMPLETED OBJECT ID:31472404
# COMPLETED OBJECT ID:31565545
# SKIPPING OBJECT ID:32246348, ONLY 5 FILTER RECORDED
# COMPLETED OBJECT ID:31848711
# SKIPPING OBJECT ID:31517646, ONLY 1 FILTER RECORDED
# SKIPPING OBJECT ID:31941316, ONLY 4 FILTER RECORDED
# SKIPPING OBJECT ID:32211149, ONLY 4 FILTER RECORDED
# SKIPPING OBJECT ID:32223805, ONLY 1 FILTER RECORDED
# SKIPPING OBJECT ID:31837086, ONLY 5 FILTER RECORDED
# COMPLETED OBJECT ID:31939482
# SKIPPING OBJECT ID:31557536, ONLY 1 FILTER RECORDED
# COMPLETED OBJECT ID:32338695
# COMPLETED OBJECT ID:31905311
# COMPLETED OBJECT ID:32015759
# COMPLETED OBJECT ID:32184607
# SKIPPING OBJECT ID:31463882, ONLY 5 FILTER RECORDED
# COMPLETED OBJECT ID:32104934
# SKIPPING OBJECT ID:32324935, ONLY 3 FILTER RECORDED
# COMPLETED OBJECT ID:32239765
# COMPLETED OBJECT ID:31957270
# COMPLETED OBJECT ID:32089287
# COMPLETED OBJECT ID:32285097
# SKIPPING OBJECT ID:32431485, ONLY 2 FILTER RECORDED
# COMPLETED OBJECT ID:32249149
# COMPLETED OBJECT ID:31681978
# SKIPPING OBJECT ID:31701600, ONLY 4 FILTER RECORDED
# SKIPPING OBJECT ID:32376660, ONLY 5 FILTER RECORDED
# COMPLETED OBJECT ID:31666304
# COMPLETED OBJECT ID:32411522
# SKIPPING OBJECT ID:32072115, ONLY 5 FILTER RECORDED
# SKIPPING OBJECT ID:31924067, ONLY 2 FILTER RECORDED
# SKIPPING OBJECT ID:31905692, ONLY 1 FILTER RECORDED
# SKIPPING OBJECT ID:31496851, ONLY 5 FILTER RECORDED
# SKIPPING OBJECT ID:32063382, ONLY 4 FILTER RECORDED
# COMPLETED OBJECT ID:31530539
# COMPLETED OBJECT ID:31961302
# COMPLETED OBJECT ID:32219592
# COMPLETED OBJECT ID:31536510
# SKIPPING OBJECT ID:32232920, ONLY 5 FILTER RECORDED
# COMPLETED OBJECT ID:32415079
# SKIPPING OBJECT ID:32105911, ONLY 1 FILTER RECORDED
# SKIPPING OBJECT ID:31675240, ONLY 5 FILTER RECORDED
# COMPLETED OBJECT ID:31528544
# SKIPPING OBJECT ID:32025159, ONLY 5 FILTER RECORDED
# COMPLETED OBJECT ID:32116647
# SKIPPING OBJECT ID:31654960, ONLY 2 FILTER RECORDED
# COMPLETED OBJECT ID:31790517
# COMPLETED OBJECT ID:32095496
# SKIPPING OBJECT ID:32345033, ONLY 5 FILTER RECORDED
# COMPLETED OBJECT ID:31456307
# SKIPPING OBJECT ID:32311709, ONLY 3 FILTER RECORDED
# COMPLETED OBJECT ID:32233116
# COMPLETED OBJECT ID:31819434
# SKIPPING OBJECT ID:31947084, ONLY 5 FILTER RECORDED
# SKIPPING OBJECT ID:31982480, ONLY 1 FILTER RECORDED
# SKIPPING OBJECT ID:31971315, ONLY 1 FILTER RECORDED
# COMPLETED OBJECT ID:31659759
# SKIPPING OBJECT ID:32037515, ONLY 5 FILTER RECORDED
# COMPLETED OBJECT ID:32236919
# COMPLETED OBJECT ID:31551997
# COMPLETED OBJECT ID:32048484
# SKIPPING OBJECT ID:32376151, ONLY 5 FILTER RECORDED
# SKIPPING OBJECT ID:31957628, ONLY 1 FILTER RECORDED

# %%
len(np.unique(generated_gp_dataset['object_id']))
# Out:
# 53

# %%
generated_gp_dataset["object_id"] = generated_gp_dataset["object_id"].astype(int)

# %%
generated_gp_dataset
# Out:
# filter           mjd       lsstg       lssti       lsstr        lsstu  \
# 0         60275.3535   13.041857   12.567481   12.993577    12.935982
# 1       60275.776065   13.497651   13.231905   13.557458    13.317075
# 2       60276.198629   13.960217   13.910273   14.131019    13.702593
# 3       60276.621194     14.4295   14.602204   14.714145    14.092426
# 4       60277.043759   14.905438   15.307261   15.306711    14.486458
# ...              ...         ...         ...         ...          ...
# 5295    60707.758789   733.89871  395.804649  522.907727   985.459429
# 5296    60708.373667  740.948474  398.033488  526.660736   992.165922
# 5297    60708.988544  747.728628   400.41858  530.187572   998.239752
# 5298    60709.603422  754.226542  403.141825  533.573848  1003.714498
# 5299      60710.2183  760.432388  406.108678  536.857897   1008.62185
#
# filter       lssty       lsstz  object_id
# 0        10.930074   11.150694   31831435
# 1        11.501257   11.796999   31831435
# 2        12.082531   12.459617   31831435
# 3        12.673409    13.13731   31831435
# 4        13.273351   13.828843   31831435
# ...            ...         ...        ...
# 5295    288.828537    334.1952   32048484
# 5296    292.803751  338.580249   32048484
# 5297    296.632638  342.754826   32048484
# 5298    300.314166  346.717228   32048484
# 5299    303.847839  350.465038   32048484
#
# [5300 rows x 8 columns]

# %%
from astronet.viz.visualise_data import plot_event, plot_event_gp_mean

# %%
plot_event_gp_mean(generated_gp_dataset, object_id=generated_gp_dataset['object_id'][0], pb_colors=ELASTICC_PB_COLORS)
# Out:
# /Users/tallamjr/mambaforge/envs/elasticc/lib/python3.10/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# (<Figure size 1200x800 with 1 Axes>, <AxesSubplot:xlabel='mjd'>)

# %%
generated_gp_dataset['hostgal_pohotoz'] = df['hostgal_photoz']
# Out:
# filter           mjd       lsstg       lssti       lsstr        lsstu  \
# 0         60275.3535   13.041857   12.567481   12.993577    12.935982
# 1       60275.776065   13.497651   13.231905   13.557458    13.317075
# 2       60276.198629   13.960217   13.910273   14.131019    13.702593
# 3       60276.621194     14.4295   14.602204   14.714145    14.092426
# 4       60277.043759   14.905438   15.307261   15.306711    14.486458
# ...              ...         ...         ...         ...          ...
# 5295    60707.758789   733.89871  395.804649  522.907727   985.459429
# 5296    60708.373667  740.948474  398.033488  526.660736   992.165922
# 5297    60708.988544  747.728628   400.41858  530.187572   998.239752
# 5298    60709.603422  754.226542  403.141825  533.573848  1003.714498
# 5299      60710.2183  760.432388  406.108678  536.857897   1008.62185
#
# filter       lssty       lsstz  object_id
# 0        10.930074   11.150694   31831435
# 1        11.501257   11.796999   31831435
# 2        12.082531   12.459617   31831435
# 3        12.673409    13.13731   31831435
# 4        13.273351   13.828843   31831435
# ...            ...         ...        ...
# 5295    288.828537    334.1952   32048484
# 5296    292.803751  338.580249   32048484
# 5297    296.632638  342.754826   32048484
# 5298    300.314166  346.717228   32048484
# 5299    303.847839  350.465038   32048484
#
# [5300 rows x 8 columns]

# %%
ddf = df[['hostgal_photoz', 'object_id', 'target']]

# %%
dfwz = generated_gp_dataset.merge(ddf, on="object_id", how="left").drop_duplicates()

# %%
dfwz
# Out:
#                  mjd       lsstg       lssti       lsstr        lsstu  \
# 0         60275.3535   13.041857   12.567481   12.993577    12.935982
# 23      60275.776065   13.497651   13.231905   13.557458    13.317075
# 46      60276.198629   13.960217   13.910273   14.131019    13.702593
# 69      60276.621194     14.4295   14.602204   14.714145    14.092426
# 92      60277.043759   14.905438   15.307261   15.306711    14.486458
# ...              ...         ...         ...         ...          ...
# 157645  60707.758789   733.89871  395.804649  522.907727   985.459429
# 157676  60708.373667  740.948474  398.033488  526.660736   992.165922
# 157707  60708.988544  747.728628   400.41858  530.187572   998.239752
# 157738  60709.603422  754.226542  403.141825  533.573848  1003.714498
# 157769    60710.2183  760.432388  406.108678  536.857897   1008.62185
#
#              lssty       lsstz  object_id  hostgal_photoz target
# 0        10.930074   11.150694   31831435        0.671085    TDE
# 23       11.501257   11.796999   31831435        0.671085    TDE
# 46       12.082531   12.459617   31831435        0.671085    TDE
# 69       12.673409    13.13731   31831435        0.671085    TDE
# 92       13.273351   13.828843   31831435        0.671085    TDE
# ...            ...         ...        ...             ...    ...
# 157645  288.828537    334.1952   32048484        0.125193    TDE
# 157676  292.803751  338.580249   32048484        0.125193    TDE
# 157707  296.632638  342.754826   32048484        0.125193    TDE
# 157738  300.314166  346.717228   32048484        0.125193    TDE
# 157769  303.847839  350.465038   32048484        0.125193    TDE
#
# [5300 rows x 10 columns]

# %%
plot_event_gp_mean(dfwz, object_id=dfwz['object_id'][0], pb_colors=ELASTICC_PB_COLORS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [20], line 1
# ----> 1 plot_event_gp_mean(dfwz, object_id=dfwz['object_id'][0], pb_colors=ELASTICC_PB_COLORS)
#
# NameError: name 'plot_event_gp_mean' is not defined
