# %%
import io
import requests

import pandas as pd
import polars as pl
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')

# %%
pdf = pd.read_parquet('../data/raw/ftransfer_elasticc_2023-02-15_946675/classId=121')

# %%
def extract_history(history_list: list, field: str) -> list:
    """Extract the historical measurements contained in the alerts
    for the parameter `field`.

    Parameters
    ----------
    history_list: list of dict
        List of dictionary from alert[history].
    field: str
        The field name for which you want to extract the data. It must be
        a key of elements of history_list
    
    Returns
    ----------
    measurement: list
        List of all the `field` measurements contained in the alerts.
    """
    if history_list is None:
        return []
    try:
        measurement = [obs[field] for obs in history_list]
    except KeyError:
        print('{} not in history data'.format(field))
        measurement = []

    return measurement

def extract_field(alert: dict, category: str, field: str, key: str) -> np.array:
    """ Concatenate current and historical observation data for a given field.
    
    Parameters
    ----------
    alert: dict
        Dictionnary containing alert data
    category: str
        prvDiaSources or prvDiaForcedSources
    field: str
        Name of the field to extract.
    
    Returns
    ----------
    data: np.array
        List containing previous measurements and current measurement at the
        end. If `field` is not in the category, data will be
        [alert['diaSource'][field]].
    """
    data = np.concatenate(
        [
            [alert[key][field]],
            extract_history(alert[category], field)
        ]
    )
    return data

# %%
pdf['target'] = 121

# %%
pdf["diaObject"][0]
# Out:
# {'decl': -49.696072651146864,
#  'diaObjectId': 146402526,
#  'hostgal2_dec': -999.0,
#  'hostgal2_ellipticity': -9999.0,
#  'hostgal2_mag_Y': 999.0,
#  'hostgal2_mag_g': 999.0,
#  'hostgal2_mag_i': 999.0,
#  'hostgal2_mag_r': 999.0,
#  'hostgal2_mag_u': 999.0,
#  'hostgal2_mag_z': 999.0,
#  'hostgal2_magerr_Y': 999.0,
#  'hostgal2_magerr_g': 999.0,
#  'hostgal2_magerr_i': 999.0,
#  'hostgal2_magerr_r': 999.0,
#  'hostgal2_magerr_u': 999.0,
#  'hostgal2_magerr_z': 999.0,
#  'hostgal2_ra': -999.0,
#  'hostgal2_snsep': -9.0,
#  'hostgal2_sqradius': -9999.0,
#  'hostgal2_zphot': -999.0,
#  'hostgal2_zphot_err': -999.0,
#  'hostgal2_zphot_p50': None,
#  'hostgal2_zphot_q000': -9.0,
#  'hostgal2_zphot_q010': -9.0,
#  'hostgal2_zphot_q020': -9.0,
#  'hostgal2_zphot_q030': -9.0,
#  'hostgal2_zphot_q040': -9.0,
#  'hostgal2_zphot_q050': -9.0,
#  'hostgal2_zphot_q060': -9.0,
#  'hostgal2_zphot_q070': -9.0,
#  'hostgal2_zphot_q080': -9.0,
#  'hostgal2_zphot_q090': -9.0,
#  'hostgal2_zphot_q100': -9.0,
#  'hostgal2_zspec': -999.0,
#  'hostgal2_zspec_err': -999.0,
#  'hostgal_dec': -49.69614791870117,
#  'hostgal_ellipticity': 0.1737000048160553,
#  'hostgal_mag_Y': 20.48383331298828,
#  'hostgal_mag_g': 21.357295989990234,
#  'hostgal_mag_i': 20.616376876831055,
#  'hostgal_mag_r': 20.849885940551758,
#  'hostgal_mag_u': 22.802539825439453,
#  'hostgal_mag_z': 20.47096824645996,
#  'hostgal_magerr_Y': 0.058607593178749084,
#  'hostgal_magerr_g': 0.053639236837625504,
#  'hostgal_magerr_i': 0.05082278326153755,
#  'hostgal_magerr_r': 0.05272151529788971,
#  'hostgal_magerr_u': 0.23857593536376953,
#  'hostgal_magerr_z': 0.05265822634100914,
#  'hostgal_ra': 0.9677252769470215,
#  'hostgal_snsep': 0.3026818335056305,
#  'hostgal_sqradius': 41.61360168457031,
#  'hostgal_zphot': 0.16344062983989716,
#  'hostgal_zphot_err': 0.16808000206947327,
#  'hostgal_zphot_p50': None,
#  'hostgal_zphot_q000': 0.014060630463063717,
#  'hostgal_zphot_q010': 0.06581062823534012,
#  'hostgal_zphot_q020': 0.09673062711954117,
#  'hostgal_zphot_q030': 0.12639063596725464,
#  'hostgal_zphot_q040': 0.139020636677742,
#  'hostgal_zphot_q050': 0.16344062983989716,
#  'hostgal_zphot_q060': 0.18916063010692596,
#  'hostgal_zphot_q070': 0.20094062387943268,
#  'hostgal_zphot_q080': 0.2242906242609024,
#  'hostgal_zphot_q090': 0.2787206172943115,
#  'hostgal_zphot_q100': 0.49551063776016235,
#  'hostgal_zspec': -999.0,
#  'hostgal_zspec_err': -999.0,
#  'mwebv': 0.009014381095767021,
#  'mwebv_err': 0.0004507190315052867,
#  'ra': 0.9676724344437256,
#  'simVersion': None,
#  'z_final': 0.16344062983989716,
#  'z_final_err': 0.16808000206947327}

# %%
print(pdf.columns)
# Out:
# Index(['alertId', 'diaSource', 'prvDiaSources', 'prvDiaForcedSources',
#        'prvDiaNondetectionLimits', 'diaObject', 'cutoutDifference',
#        'cutoutTemplate', 'brokerIngestTimestamp', 'timestamp',
#        'rf_snia_vs_nonia', 'snn_snia_vs_nonia', 'snn_broad_class',
#        'snn_broad_max_prob', 'cats_broad_class', 'cats_broad_max_prob',
#        'cats_fine_class', 'cats_fine_max_prob', 'rf_agn_vs_nonagn',
#        't2_broad_class', 't2_broad_max_prob', 'fink_broker_version',
#        'fink_science_version', 'publisher', 'SNID', 'LIBID',
#        'SIM_SEARCHEFF_MASK', 'GENTYPE', 'SIM_TEMPLATE_INDEX', 'ZCMB', 'ZHELIO',
#        'ZCMB_SMEAR', 'RA', 'DEC', 'MWEBV', 'GALNMATCH', 'GALID', 'GALZPHOT',
#        'GALZPHOTERR', 'GALSNSEP', 'GALSNDDLR', 'RV', 'AV', 'MU', 'LENSDMU',
#        'PEAKMJD', 'MJD_DETECT_FIRST', 'MJD_DETECT_LAST', 'DTSEASON_PEAK',
#        'PEAKMAG_u', 'PEAKMAG_g', 'PEAKMAG_r', 'PEAKMAG_i', 'PEAKMAG_z',
#        'PEAKMAG_Y', 'SNRMAX', 'SNRMAX2', 'SNRMAX3', 'NOBS', 'NOBS_SATURATE',
#        'year', 'month', 'day', 'target'],
#       dtype='object')

# %%
pdf["NOBS"][0]
# Out:
# 149

# %%
pdf['cpsFlux'] = pdf[['diaSource', 'prvDiaForcedSources']]\
    .apply(lambda x: extract_field(x, 'prvDiaForcedSources', 'psFlux', 'diaSource'), axis=1)
pdf['cpsFluxErr'] = pdf[['diaSource', 'prvDiaForcedSources']]\
    .apply(lambda x: extract_field(x, 'prvDiaForcedSources', 'psFluxErr', 'diaSource'), axis=1)
pdf['cfilterName'] = pdf[['diaSource', 'prvDiaForcedSources']]\
    .apply(lambda x: extract_field(x, 'prvDiaForcedSources', 'filterName', 'diaSource'), axis=1)
pdf['cmidPointTai'] = pdf[['diaSource', 'prvDiaForcedSources']]\
    .apply(lambda x: extract_field(x, 'prvDiaForcedSources', 'midPointTai', 'diaSource'), axis=1)

pdf['cZ'] = pdf[['diaObject', 'prvDiaForcedSources']]\
    .apply(lambda x: extract_field(x, 'prvDiaForcedSources', 'z_final', 'diaObject'), axis=1)
pdf['cZerr'] = pdf[['diaObject', 'prvDiaForcedSources']]\
    .apply(lambda x: extract_field(x, 'prvDiaForcedSources', 'z_final_err', 'diaObject'), axis=1)
pdf['cMwebv'] = pdf[['diaObject', 'prvDiaForcedSources']]\
    .apply(lambda x: extract_field(x, 'prvDiaForcedSources', 'mwebv', 'diaObject'), axis=1)
pdf['cRa'] = pdf[['diaObject', 'prvDiaForcedSources']]\
    .apply(lambda x: extract_field(x, 'prvDiaForcedSources', 'ra', 'diaObject'), axis=1)
pdf['cDecl'] = pdf[['diaObject', 'prvDiaForcedSources']]\
    .apply(lambda x: extract_field(x, 'prvDiaForcedSources', 'decl', 'diaObject'), axis=1)
pdf['cHostgal_ra'] = pdf[['diaObject', 'prvDiaForcedSources']]\
    .apply(lambda x: extract_field(x, 'prvDiaForcedSources', 'hostgal_ra', 'diaObject'), axis=1)
pdf['cHostgal_dec'] = pdf[['diaObject', 'prvDiaForcedSources']]\
    .apply(lambda x: extract_field(x, 'prvDiaForcedSources', 'hostgal_dec', 'diaObject'), axis=1)

cols = ['alertId', 'target', 'cmidPointTai', 'cpsFlux', 'cpsFluxErr', 'cfilterName', 'cZ', \
        'cZerr', 'cMwebv', 'cRa', 'cDecl', 'cHostgal_ra', 'cHostgal_dec', \
        'SNID', 'NOBS']
sub = pdf[cols]
sub
# Out:
# z_final not in history data
# z_final not in history data
# z_final not in history data
# z_final not in history data
# z_final not in history data
# z_final_err not in history data
# z_final_err not in history data
# z_final_err not in history data
# z_final_err not in history data
# z_final_err not in history data
# mwebv not in history data
# mwebv not in history data
# mwebv not in history data
# mwebv not in history data
# mwebv not in history data
# ra not in history data
# ra not in history data
# ra not in history data
# ra not in history data
# ra not in history data
# decl not in history data
# decl not in history data
# decl not in history data
# decl not in history data
# decl not in history data
# hostgal_ra not in history data
# hostgal_ra not in history data
# hostgal_ra not in history data
# hostgal_ra not in history data
# hostgal_ra not in history data
# hostgal_dec not in history data
# hostgal_dec not in history data
# hostgal_dec not in history data
# hostgal_dec not in history data
# hostgal_dec not in history data
#          alertId  target                                       cmidPointTai  \
# 0   292805052048     121                                       [60607.0736]
# 1   236811186028     121                                       [60320.1313]
# 2   181886744009     121                                       [60549.1873]
# 3   221478330013     121                                       [60609.3722]
# 4   250750812072     121                                        [60466.004]
# 5   164227482030     121  [60340.3594, 60314.2508, 60314.2756, 60314.286...
# 6   164227482031     121  [60340.3716, 60314.2508, 60314.2756, 60314.286...
# 7   164227482029     121  [60340.3479, 60314.2508, 60314.2756, 60314.286...
# 8    38666284032     121                                       [60593.2405]
# 9    38666284033     121                                       [60593.2654]
# 10  188974560023     121                                        [60449.392]
# 11   21885874057     121                                       [60401.2351]
# 12   21885874058     121                                       [60401.2592]
# 13  113455926026     121                                       [60639.2772]
# 14  113455926027     121                                       [60639.3011]
# 15  284710352078     121                                       [60413.1697]
# 16  284710352077     121                                       [60413.1478]
# 17  284710352079     121                                       [60413.1939]
# 18   21885874059     121  [60402.2838, 60373.1789, 60373.2036, 60374.358...
# 19  152806952035     121                                       [60407.3671]
# 20  152806952036     121                                       [60407.3945]
# 21  214914676003     121                                       [60380.3567]
# 22  214914676002     121                                        [60380.335]
# 23  161741654045     121                                        [60527.244]
# 24   22178354054     121                                       [60505.0265]
# 25   22178354056     121  [60505.9886, 60485.2627, 60485.2858, 60487.110...
# 26   22178354055     121                                       [60505.0509]
# 27   49535798018     121                                        [60441.303]
# 28  172488826000     121                                       [60382.3401]
# 29  234268736069     121                                       [60611.0138]
# 30  139620698044     121                                        [60574.073]
# 31  139620698046     121                                       [60574.1325]
# 32  139620698045     121                                       [60574.1083]
# 33  250566034046     121                                       [60345.1643]
# 34  149564050037     121                                       [60345.2016]
# 35  149564050036     121                                       [60345.1994]
# 36  250750812071     121                                       [60465.9796]
# 37   34789836006     121                                       [60465.4221]
# 38  164227482027     121                                       [60339.3247]
# 39   10997036035     121                                       [60379.3348]
#
#                                               cpsFlux  \
# 0                                   [517.75732421875]
# 1                                 [1169.298583984375]
# 2                                  [1041.65673828125]
# 3                                  [2575.27392578125]
# 4                                 [1167.426513671875]
# 5   [4735.275390625, -231.21820068359375, -552.134...
# 6   [4800.42529296875, -231.21820068359375, -552.1...
# 7   [4983.572265625, -231.21820068359375, -552.134...
# 8                                 [791.9251098632812]
# 9                                 [1764.031982421875]
# 10                                [1062.924072265625]
# 11                                     [6169.6171875]
# 12                                    [7483.49609375]
# 13                               [390.53985595703125]
# 14                                [1557.525634765625]
# 15                                 [1688.89697265625]
# 16                                   [3052.951171875]
# 17                                [2391.405029296875]
# 18  [2180.092041015625, 21.62727165222168, -357.32...
# 19                                     [4238.7890625]
# 20                                [3735.663330078125]
# 21                                 [2195.80029296875]
# 22                                [1652.019287109375]
# 23                               [1429.5511474609375]
# 24                                 [5127.33935546875]
# 25  [1518.2388916015625, -132.09169006347656, 3814...
# 26                                      [5063.359375]
# 27                                   [1889.771484375]
# 28                                [2846.702880859375]
# 29                                [893.6707153320312]
# 30                               [2020.8924560546875]
# 31                                 [3208.44580078125]
# 32                                [2049.185302734375]
# 33                               [1847.2718505859375]
# 34                                [3480.814208984375]
# 35                                  [4076.2744140625]
# 36                                 [1271.70751953125]
# 37                                [714.8418579101562]
# 38                                [3695.597900390625]
# 39                                [578.6421508789062]
#
#                                            cpsFluxErr  \
# 0                                [221.70233154296875]
# 1                                 [196.1234130859375]
# 2                                [273.07745361328125]
# 3                                 [692.6956787109375]
# 4                                [206.24415588378906]
# 5   [644.0177001953125, 310.8291015625, 462.648345...
# 6   [693.317138671875, 310.8291015625, 462.6483459...
# 7   [417.4020080566406, 310.8291015625, 462.648345...
# 8                                [153.12400817871094]
# 9                                   [156.42236328125]
# 10                               [181.26617431640625]
# 11                               [441.26446533203125]
# 12                                [706.8509521484375]
# 13                                 [97.6305160522461]
# 14                               [151.06932067871094]
# 15                                [412.8540344238281]
# 16                                [506.2305908203125]
# 17                                [440.5065612792969]
# 18  [384.5772705078125, 132.51869201660156, 165.11...
# 19                                [238.8812255859375]
# 20                                   [278.8369140625]
# 21                                [262.1972351074219]
# 22                                [144.9216766357422]
# 23                                  [458.10302734375]
# 24                               [348.83465576171875]
# 25  [575.2952880859375, 1908.2532958984375, 1704.3...
# 26                                [469.2696228027344]
# 27                               [154.85653686523438]
# 28                                [603.6016845703125]
# 29                               [176.92584228515625]
# 30                               [276.64007568359375]
# 31                                [529.0969848632812]
# 32                                 [346.563720703125]
# 33                               [231.81370544433594]
# 34                               [250.38705444335938]
# 35                                [257.5848083496094]
# 36                               [134.34735107421875]
# 37                                [126.7337646484375]
# 38                                [863.7949829101562]
# 39                                [202.0797119140625]
#
#                                           cfilterName                      cZ  \
# 0                                                 [i]   [0.16344062983989716]
# 1                                                 [i]    [0.1338547170162201]
# 2                                                 [r]   [0.23332324624061584]
# 3                                                 [r]  [0.050953783094882965]
# 4                                                 [i]    [0.1325898915529251]
# 5   [z, i, z, z, Y, r, i, r, r, r, r, r, i, i, Y, ...   [0.11739850789308548]
# 6   [z, i, z, z, Y, r, i, r, r, r, r, r, i, i, Y, ...   [0.11739850789308548]
# 7   [i, i, z, z, Y, r, i, r, r, r, r, r, i, i, Y, ...   [0.11739850789308548]
# 8                                                 [g]   [0.16801081597805023]
# 9                                                 [r]   [0.16801081597805023]
# 10                                                [r]   [0.12380369752645493]
# 11                                                [z]  [0.039679743349552155]
# 12                                                [Y]  [0.039679743349552155]
# 13                                                [g]   [0.19342194497585297]
# 14                                                [r]   [0.19342194497585297]
# 15                                                [r]   [0.15352922677993774]
# 16                                                [i]   [0.15352922677993774]
# 17                                                [i]   [0.15352922677993774]
# 18  [z, g, r, i, i, u, u, g, g, u, u, g, u, r, u, ...  [0.039679743349552155]
# 19                                                [r]      [2.64398193359375]
# 20                                                [i]      [2.64398193359375]
# 21                                                [i]   [0.06633619219064713]
# 22                                                [r]   [0.06633619219064713]
# 23                                                [g]   [0.12081736326217651]
# 24                                                [i]    [0.4057801365852356]
# 25  [i, Y, Y, z, i, r, r, i, i, g, r, r, i, u, r, ...    [0.4057801365852356]
# 26                                                [z]    [0.4057801365852356]
# 27                                                [r]   [0.18279826641082764]
# 28                                                [i]   [0.08607642352581024]
# 29                                                [r]    [0.2617603540420532]
# 30                                                [i]   [0.11319953948259354]
# 31                                                [z]   [0.11319953948259354]
# 32                                                [i]   [0.11319953948259354]
# 33                                                [r]    [2.7958974838256836]
# 34                                                [r]   [0.01209842786192894]
# 35                                                [r]   [0.01209842786192894]
# 36                                                [r]    [0.1325898915529251]
# 37                                                [r]    [0.2879013419151306]
# 38                                                [z]   [0.11739850789308548]
# 39                                                [r]   [0.08110382407903671]
#
#                       cZerr                  cMwebv                   cRa  \
# 0     [0.16808000206947327]  [0.009014381095767021]  [0.9676724344437256]
# 1      [0.1252799928188324]   [0.00950966402888298]   [69.52126616511217]
# 2     [0.22684000432491302]  [0.006137879565358162]   [2.553227017279791]
# 3   [0.0010000000474974513]  [0.014673247002065182]   [57.33047750559256]
# 4   [0.0010000000474974513]   [0.08095170557498932]  [188.22928460733328]
# 5     [0.13095000386238098]   [0.05223875492811203]  [157.65726394121165]
# 6     [0.13095000386238098]   [0.05223875492811203]  [157.65726394121165]
# 7     [0.13095000386238098]   [0.05223875492811203]  [157.65726394121165]
# 8      [0.1820099949836731]  [0.012775149196386337]   [24.38803778053321]
# 9      [0.1820099949836731]  [0.012775149196386337]   [24.38803778053321]
# 10    [0.13715000450611115]   [0.15334530174732208]   [287.3108554690964]
# 11  [0.0010000000474974513]   [0.05719093605875969]  [182.52191475033388]
# 12  [0.0010000000474974513]   [0.05719093605875969]  [182.52191475033388]
# 13    [0.21131999790668488]  [0.006713836919516325]    [58.4831112403628]
# 14    [0.21131999790668488]  [0.006713836919516325]    [58.4831112403628]
# 15  [0.0010000000474974513]   [0.06140700727701187]  [160.16129492063584]
# 16  [0.0010000000474974513]   [0.06140700727701187]  [160.16129492063584]
# 17  [0.0010000000474974513]   [0.06140700727701187]  [160.16129492063584]
# 18  [0.0010000000474974513]   [0.05719093605875969]  [182.52191475033388]
# 19     [2.6438701152801514]   [0.10571995377540588]  [225.05860276947357]
# 20     [2.6438701152801514]   [0.10571995377540588]  [225.05860276947357]
# 21  [0.0010000000474974513]    [0.1239488422870636]  [240.14479205049483]
# 22  [0.0010000000474974513]    [0.1239488422870636]  [240.14479205049483]
# 23    [0.13262000679969788]   [0.06909733265638351]   [306.3698389717665]
# 24     [0.4137299954891205]   [0.11362776160240173]  [261.71389743791696]
# 25     [0.4137299954891205]   [0.11362776160240173]  [261.71389743791696]
# 26     [0.4137299954891205]   [0.11362776160240173]  [261.71389743791696]
# 27      [0.195360004901886]   [0.06183145195245743]  [288.02405725100704]
# 28  [0.0010000000474974513]   [0.07250604778528214]  [250.41458512600465]
# 29    [0.25586000084877014]   [0.07270494103431702]  [304.42405969016704]
# 30    [0.12115000188350677]   [0.04155983030796051]  [323.72869895822225]
# 31    [0.12115000188350677]   [0.04155983030796051]  [323.72869895822225]
# 32    [0.12115000188350677]   [0.04155983030796051]  [323.72869895822225]
# 33      [2.799639940261841]   [0.03962703049182892]  [139.22057578431023]
# 34    [0.02085000090301037]  [0.029038814827799797]  [145.26619030123064]
# 35    [0.02085000090301037]  [0.029038814827799797]  [145.26619030123064]
# 36  [0.0010000000474974513]   [0.08095170557498932]  [188.22928460733328]
# 37     [0.2838500142097473]   [0.05398571118712425]  [317.94805700647106]
# 38    [0.13095000386238098]   [0.05223875492811203]  [157.65726394121165]
# 39  [0.0010000000474974513]   [0.03566484525799751]   [192.6714825565366]
#
#                     cDecl           cHostgal_ra           cHostgal_dec  \
# 0   [-49.696072651146864]  [0.9677252769470215]   [-49.69614791870117]
# 1    [-50.38369680355572]   [69.52117156982422]   [-50.38372802734375]
# 2    [-43.31437494725598]  [2.5532901287078857]    [-43.3144645690918]
# 3    [-53.56728248804294]   [57.33053207397461]  [-53.567298889160156]
# 4    [-40.88442885410509]  [188.22918701171875]   [-40.88450622558594]
# 5   [-22.807671218881783]  [157.65725708007812]  [-22.807472229003906]
# 6   [-22.807671218881783]  [157.65725708007812]  [-22.807472229003906]
# 7   [-22.807671218881783]  [157.65725708007812]  [-22.807472229003906]
# 8    [-45.10943347471609]   [24.38807487487793]   [-45.10942840576172]
# 9    [-45.10943347471609]   [24.38807487487793]   [-45.10942840576172]
# 10   [-19.62658580345473]   [287.3106384277344]  [-19.626474380493164]
# 11  [-31.762338815591793]  [182.52183532714844]   [-31.76241111755371]
# 12  [-31.762338815591793]  [182.52183532714844]   [-31.76241111755371]
# 13   [-42.67702133610946]  [58.483150482177734]   [-42.67701721191406]
# 14   [-42.67702133610946]  [58.483150482177734]   [-42.67701721191406]
# 15  [-24.038652574547772]   [160.1613311767578]  [-24.038986206054688]
# 16  [-24.038652574547772]   [160.1613311767578]  [-24.038986206054688]
# 17  [-24.038652574547772]   [160.1613311767578]  [-24.038986206054688]
# 18  [-31.762338815591793]  [182.52183532714844]   [-31.76241111755371]
# 19  [-35.557621440551486]   [225.0585479736328]   [-35.55753707885742]
# 20  [-35.557621440551486]   [225.0585479736328]   [-35.55753707885742]
# 21    [3.033228936492043]  [240.14381408691406]    [3.033234119415283]
# 22    [3.033228936492043]  [240.14381408691406]    [3.033234119415283]
# 23   [-8.681707215017433]   [306.3697509765625]   [-8.681624412536621]
# 24   [-56.57013324218278]      [261.7138671875]  [-56.570159912109375]
# 25   [-56.57013324218278]      [261.7138671875]  [-56.570159912109375]
# 26   [-56.57013324218278]      [261.7138671875]  [-56.570159912109375]
# 27    [-50.3112511319894]   [288.0238342285156]  [-50.311363220214844]
# 28   [-67.22757652362297]  [250.41488647460938]   [-67.22771453857422]
# 29  [-27.260443680239668]    [304.424072265625]  [-27.260435104370117]
# 30   [-5.037512636388612]    [323.728759765625]   [-5.037339210510254]
# 31   [-5.037512636388612]    [323.728759765625]   [-5.037339210510254]
# 32   [-5.037512636388612]    [323.728759765625]   [-5.037339210510254]
# 33   [-12.84984525123278]   [139.2205810546875]  [-12.849942207336426]
# 34  [-2.6678531698413686]  [145.26760864257812]  [-2.6682841777801514]
# 35  [-2.6678531698413686]  [145.26760864257812]  [-2.6682841777801514]
# 36   [-40.88442885410509]  [188.22918701171875]   [-40.88450622558594]
# 37  [-25.415899961982856]    [317.947998046875]   [-25.41594886779785]
# 38  [-22.807671218881783]  [157.65725708007812]  [-22.807472229003906]
# 39  [-12.112497194910018]   [192.6715087890625]  [-12.112525939941406]
#
#          SNID  NOBS
# 0   146402526   149
# 1   118405593   127
# 2    90943372   237
# 3   110739165   115
# 4   125375406   157
# 5    82113741   163
# 6    82113741   163
# 7    82113741   163
# 8    19333142   236
# 9    19333142   236
# 10   94487280   128
# 11   10942937   156
# 12   10942937   156
# 13   56727963   211
# 14   56727963   211
# 15  142355176   150
# 16  142355176   150
# 17  142355176   150
# 18   10942937   156
# 19   76403476   162
# 20   76403476   162
# 21  107457338   163
# 22  107457338   163
# 23   80870827   236
# 24   11089177   173
# 25   11089177   173
# 26   11089177   173
# 27   24767899   106
# 28   86244413   170
# 29  117134368   102
# 30   69810349   219
# 31   69810349   219
# 32   69810349   219
# 33  125283017   162
# 34   74782025   177
# 35   74782025   177
# 36  125375406   157
# 37   17394918    95
# 38   82113741   163
# 39    5498518   156

# %%
sub.shape
# Out:
# (40, 15)

# %%
def f(x):
    y = len(list(set(x))) > 1
    #sample function
    return y 

df = sub["cfilterName"].apply(f)
sub = sub[df].reset_index()

# %%
def f(x):
    y = len(x) > 1
    #sample function
    return y 

df = sub["cmidPointTai"].apply(f)
sub = sub[df].reset_index(drop=True)

# %%
sub
# Out:
#    index       alertId  target  \
# 0      5  164227482030     121
# 1      6  164227482031     121
# 2      7  164227482029     121
# 3     18   21885874059     121
# 4     25   22178354056     121
#
#                                         cmidPointTai  \
# 0  [60340.3594, 60314.2508, 60314.2756, 60314.286...
# 1  [60340.3716, 60314.2508, 60314.2756, 60314.286...
# 2  [60340.3479, 60314.2508, 60314.2756, 60314.286...
# 3  [60402.2838, 60373.1789, 60373.2036, 60374.358...
# 4  [60505.9886, 60485.2627, 60485.2858, 60487.110...
#
#                                              cpsFlux  \
# 0  [4735.275390625, -231.21820068359375, -552.134...
# 1  [4800.42529296875, -231.21820068359375, -552.1...
# 2  [4983.572265625, -231.21820068359375, -552.134...
# 3  [2180.092041015625, 21.62727165222168, -357.32...
# 4  [1518.2388916015625, -132.09169006347656, 3814...
#
#                                           cpsFluxErr  \
# 0  [644.0177001953125, 310.8291015625, 462.648345...
# 1  [693.317138671875, 310.8291015625, 462.6483459...
# 2  [417.4020080566406, 310.8291015625, 462.648345...
# 3  [384.5772705078125, 132.51869201660156, 165.11...
# 4  [575.2952880859375, 1908.2532958984375, 1704.3...
#
#                                          cfilterName                      cZ  \
# 0  [z, i, z, z, Y, r, i, r, r, r, r, r, i, i, Y, ...   [0.11739850789308548]
# 1  [z, i, z, z, Y, r, i, r, r, r, r, r, i, i, Y, ...   [0.11739850789308548]
# 2  [i, i, z, z, Y, r, i, r, r, r, r, r, i, i, Y, ...   [0.11739850789308548]
# 3  [z, g, r, i, i, u, u, g, g, u, u, g, u, r, u, ...  [0.039679743349552155]
# 4  [i, Y, Y, z, i, r, r, i, i, g, r, r, i, u, r, ...    [0.4057801365852356]
#
#                      cZerr                 cMwebv                   cRa  \
# 0    [0.13095000386238098]  [0.05223875492811203]  [157.65726394121165]
# 1    [0.13095000386238098]  [0.05223875492811203]  [157.65726394121165]
# 2    [0.13095000386238098]  [0.05223875492811203]  [157.65726394121165]
# 3  [0.0010000000474974513]  [0.05719093605875969]  [182.52191475033388]
# 4     [0.4137299954891205]  [0.11362776160240173]  [261.71389743791696]
#
#                    cDecl           cHostgal_ra           cHostgal_dec  \
# 0  [-22.807671218881783]  [157.65725708007812]  [-22.807472229003906]
# 1  [-22.807671218881783]  [157.65725708007812]  [-22.807472229003906]
# 2  [-22.807671218881783]  [157.65725708007812]  [-22.807472229003906]
# 3  [-31.762338815591793]  [182.52183532714844]   [-31.76241111755371]
# 4   [-56.57013324218278]      [261.7138671875]  [-56.570159912109375]
#
#        SNID  NOBS
# 0  82113741   163
# 1  82113741   163
# 2  82113741   163
# 3  10942937   156
# 4  11089177   173

# %%
sub = pl.from_pandas(sub)

# %%
df = sub.explode(["cmidPointTai", "cpsFlux", "cpsFluxErr", "cfilterName"]).sort(by=["index", "cfilterName"])

df = df.explode(["cZ", "cZerr", "cMwebv", "cRa", "cDecl", "cHostgal_ra", "cHostgal_dec"])

df = df.rename({"SNID": "object_id","cmidPointTai": "mjd", "cpsFlux": "flux", "cpsFluxErr": "flux_error", "cfilterName": "filter", "cZ": "z", "cZerr": "z_error", "cMwebv": "mwebv", "cRa": "ra", "cDecl": "dec", "cHostgal_ra": "hostgal_ra", "cHostgal_dec": "hostgal_dec", "NOBS":"nobs"})

df
# Out:
# shape: (123, 16)
# ┌───────┬──────────────┬────────┬────────────┬─────┬────────────┬─────────────┬───────────┬──────┐
# │ index ┆ alertId      ┆ target ┆ mjd        ┆ ... ┆ hostgal_ra ┆ hostgal_dec ┆ object_id ┆ nobs │
# │ ---   ┆ ---          ┆ ---    ┆ ---        ┆     ┆ ---        ┆ ---         ┆ ---       ┆ ---  │
# │ i64   ┆ i64          ┆ i64    ┆ f64        ┆     ┆ f64        ┆ f64         ┆ i64       ┆ i64  │
# ╞═══════╪══════════════╪════════╪════════════╪═════╪════════════╪═════════════╪═══════════╪══════╡
# │ 5     ┆ 164227482030 ┆ 121    ┆ 60314.3082 ┆ ... ┆ 157.657257 ┆ -22.807472  ┆ 82113741  ┆ 163  │
# │ 5     ┆ 164227482030 ┆ 121    ┆ 60327.3531 ┆ ... ┆ 157.657257 ┆ -22.807472  ┆ 82113741  ┆ 163  │
# │ 5     ┆ 164227482030 ┆ 121    ┆ 60327.3627 ┆ ... ┆ 157.657257 ┆ -22.807472  ┆ 82113741  ┆ 163  │
# │ 5     ┆ 164227482030 ┆ 121    ┆ 60335.3411 ┆ ... ┆ 157.657257 ┆ -22.807472  ┆ 82113741  ┆ 163  │
# │ ...   ┆ ...          ┆ ...    ┆ ...        ┆ ... ┆ ...        ┆ ...         ┆ ...       ┆ ...  │
# │ 25    ┆ 22178354056  ┆ 121    ┆ 60493.0226 ┆ ... ┆ 261.713867 ┆ -56.57016   ┆ 11089177  ┆ 173  │
# │ 25    ┆ 22178354056  ┆ 121    ┆ 60487.1102 ┆ ... ┆ 261.713867 ┆ -56.57016   ┆ 11089177  ┆ 173  │
# │ 25    ┆ 22178354056  ┆ 121    ┆ 60503.9988 ┆ ... ┆ 261.713867 ┆ -56.57016   ┆ 11089177  ┆ 173  │
# │ 25    ┆ 22178354056  ┆ 121    ┆ 60505.0509 ┆ ... ┆ 261.713867 ┆ -56.57016   ┆ 11089177  ┆ 173  │
# └───────┴──────────────┴────────┴────────────┴─────┴────────────┴─────────────┴───────────┴──────┘

# %%
len(df["alertId"].unique())
# Out:
# 5

# %%
from astronet.preprocess import generate_gp_all_objects, remap_filters, generate_gp_single_event
from astronet.constants import *

# %%
df = remap_filters(df, filter_map=ELASTICC_FILTER_MAP)
df
# Out:
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 df = remap_filters(df, filter_map=ELASTICC_FILTER_MAP)
#       2 df
#
# File ~/github/tallamjr/origin/astronet/astronet/preprocess.py:428, in remap_filters(df, filter_map)
#     417 """Function to remap integer filters to the corresponding filters.
#     418
#     419 Parameters
#    (...)
#     425     {LSST_FILTER_MAP, ZTF_FILTER_MAP}
#     426 """
#     427 # df["filter"].replace(to_replace=filter_map, inplace=True)
# --> 428 df.select(pl.all().map_dict(filter_map, default=pl.col("filter")))
#     429 return df
#
# File ~/mambaforge/envs/elasticc/lib/python3.10/site-packages/polars/internals/dataframe/frame.py:5865, in DataFrame.select(self, exprs, *more_exprs, **named_exprs)
#    5756 def select(
#    5757     self,
#    5758     exprs: IntoExpr | Iterable[IntoExpr] | None = None,
#    5759     *more_exprs: IntoExpr,
#    5760     **named_exprs: IntoExpr,
#    5761 ) -> Self:
#    5762     """
#    5763     Select columns from this DataFrame.
#    5764
#    (...)
#    5862
#    5863     """
#    5864     return self._from_pydf(
# -> 5865         self.lazy()
#    5866         .select(exprs, *more_exprs, **named_exprs)
#    5867         .collect(no_optimization=True)
#    5868         ._df
#    5869     )
#
# File ~/mambaforge/envs/elasticc/lib/python3.10/site-packages/polars/internals/lazyframe/frame.py:1148, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, no_optimization, slice_pushdown, common_subplan_elimination, streaming)
#    1137     common_subplan_elimination = False
#    1139 ldf = self._ldf.optimization_toggle(
#    1140     type_coercion,
#    1141     predicate_pushdown,
#    (...)
#    1146     streaming,
#    1147 )
# -> 1148 return pli.wrap_df(ldf.collect())
#
# ComputeError: ColumnNotFoundError: filter
#
# > Error originated just after operation: '  LEFT JOIN:
#   LEFT PLAN ON: [col("index")]
#     DF ["index"]; PROJECT */1 COLUMNS; SELECTION: "None"
#   RIGHT PLAN ON: [col("__POLARS_REMAP_KEY_index")]
#      WITH_COLUMNS:
#      [true.alias("__POLARS_REMAP_IS_REMAPPED_index")]
#       DF ["__POLARS_REMAP_KEY_index", "__POLARS_REMAP_VALUE_index"]; PROJECT */2 COLUMNS; SELECTION: "None"
#   END LEFT JOIN
# '
# This operation could not be added to the plan.

# %%
df.shape[1]

# %%
ddf = df.drop(columns=["index"])

# %%
alert_list = list(np.unique(ddf["object_id"]))
len(alert_list)

# %%
# %%timeit -n1 -r1
generated_gp_dataset = generate_gp_all_objects(alert_list, ddf)

# %%
generated_gp_dataset

# %%
ddf = df.drop(columns=["mjd", "filter", "flux", "flux_error"])

# %%
ddf

# %%
df_with_xfeats = generated_gp_dataset.merge(ddf, on="object_id", how="inner")
df_with_xfeats

# %%
df_with_xfeats.drop_duplicates(keep='first', inplace=True, ignore_index=True)

# %%
df_with_xfeats

# %%
len(generated_gp_dataset["object_id"].unique())

# %%
from astronet.viz.visualise_data import *
import random

# %%
data = ddf[ddf["object_id"] == random.choice(alert_list)]

# %%
data

# %%
len(data["filter"].unique())

# %%
_obj_gps = generate_gp_single_event(data)
ax = plot_event_data_with_model(data, obj_model=_obj_gps, pb_colors=ELASTICC_PB_COLORS)

# %%
_obj_gps

# %%
_obj_gps["filter"].unique()

# %%
# N = 3
# seed = np.random.seed(1)
# indices = np.random.randint(0, len(sub), N)

# for index in indices:
#     fig = plt.figure(figsize=(12, 6))
    
#     data = sub.iloc[index]
#     filters = np.unique(data['cfilterName'])
    
#     for filt in filters:
#         cond = data['cfilterName'] == filt
        
#         plt.errorbar(
#             data['cmidPointTai'][cond], 
#             data['cpsFlux'][cond], 
#             data['cpsFluxErr'][cond],
#             ls='',
#             marker='o',
#             label='{} band'.format(filt)
#         )
#     plt.title('ID {} -- class: {}'.format(data['alertId'], data['classId']))
#     plt.legend()
#     plt.show()
